# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# plot a sine wave
x = np.linspace(0, 2 * np.pi, 100)
y = np.sin(x)
plt.plot(x, y)
plt.show()
